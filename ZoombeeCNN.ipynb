# %% [markdown]
# O notebook apresenta uma descrição dos experimentos realizados para treinar um modelo de aprendizado de máquina com o objetivo de classificar imagens do conjunto de dados Snapshot Serengeti. Esse conjunto consiste em uma grande coleção de imagens de animais selvagens capturadas no Parque Nacional Serengeti, localizado na Tanzânia, e está disponível através do link https://lila.science/datasets/snapshot-serengeti.
#
# Para o treinamento, foram utilizadas imagens das primeiras e décimas temporadas, sendo realizada uma segmentação dos dados para obter as classes mais frequentes, ou seja, aquelas com número de imagens superior a 300. Essa segmentação resultou em 15 classes principais para o treinamento.
#
# Inicialmente, utilizou-se uma rede neural convolucional Resnet-18 pré-treinada, que obteve um desempenho considerável, atingindo cerca de 85% de precisão após diversos treinamentos. Posteriormente, foram realizados outros treinamentos utilizando-se uma rede neural convolucional mais simples, a AlexNet, porém os resultados obtidos foram inferiores, com uma precisão de cerca de 77%.

# %%
#Bibliotecas utilizadas
import os
import time
import torch
import torchvision
import torchvision.transforms as T
from skimage import io
import pandas as pd
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
# %matplotlib inline
from PIL import Image
from torch.nn.parallel import DataParallel

from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score

# %%
n = 0
train_l_sum = 0.0
train_acc_sum = 0.0
start = time.time()

#Hiperparâmetros para treinamento da Rede Neural 
args = {
    'batch_size': 256,
    'num_workers': 4,
    'num_epochs': 50,
    'learning_rate': 0.001
}


device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
#Clase para utilização de um conjunto de dados personalizados
class AnimalImageDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.annotations = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, index):
        img_name = self.annotations['image_path_rel'][index]
        image = io.imread(img_name)
        y_label = torch.tensor(self.annotations['label'][index])

        if self.transform:
            image = self.transform(image)

        return image, y_label

# %%
#Paraleliza o treinamento em duas gpus
DataParallel.device_ids = [0,1]

model = DataParallel(torchvision.models.alexnet(pretrained=True))
model.to(device)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/parallel/data_parallel.py:30: UserWarning:
#     There is an imbalance between your GPUs. You may want to exclude GPU 1 which
#     has less than 75% of the memory or cores of GPU 0. You can do so by setting
#     the device_ids argument to DataParallel, or by setting the CUDA_VISIBLE_DEVICES
#     environment variable.
#   warnings.warn(imbalance_warn.format(device_ids[min_pos], device_ids[max_pos]))
# DataParallel(
#   (module): AlexNet(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#     (classifier): Sequential(
#       (0): Dropout(p=0.5, inplace=False)
#       (1): Linear(in_features=9216, out_features=4096, bias=True)
#       (2): ReLU(inplace=True)
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Linear(in_features=4096, out_features=4096, bias=True)
#       (5): ReLU(inplace=True)
#       (6): Linear(in_features=4096, out_features=1000, bias=True)
#     )
#   )
# )

# %% [markdown]
# ### Modelo ###
# A ResNet18 é uma rede neural convolucional pré-treinada com 18 camadas, amplamente utilizada em tarefas de classificação de imagens. Sua eficiência é comprovada por ser relativamente pequena em comparação com outras arquiteturas mais profundas, o que requer um desempenho computacional menor. A ResNet18 é pré-treinada em grandes conjuntos de dados, como o ImageNet, permitindo que ela aprenda recursos básicos de baixo nível.

# %%
# Model Resnet18 
model = torchvision.models.resnet18(pretrained=True)
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
train_losses = []
test_losses = []
train_correct = []
test_correct = []

#Define e retorna o DataLoader
def load_data():
    train_loader = DataLoader(dataset=train_dataset,
                              batch_size = args['batch_size'],
                              shuffle=True,
                              pin_memory = True,
                              num_workers=4)

    val_loader =  DataLoader(dataset=val_dataset,
                             batch_size = args['batch_size'],
                             shuffle=False,
                             pin_memory = True,
                             num_workers=4)

    return train_loader, val_loader


#Obtém a acurácia da rede em cima de um conjunto de dados
def evaluate_accuracy(data_iter, net, loss):
    acc_sum, n, l = torch.Tensor([0]), 0, 0
    net.eval()
    with torch.no_grad():
        for X, y in data_iter:
            X, y = X.to(device), y.to(device)
            # Apply the model
            y_hat = net(X)
            l += loss(y_hat, y).sum()
            acc_sum += (y_hat.argmax(axis=1) == y).sum().item()
            n += y.size()[0]
    return acc_sum.item() / n, l.item() / len(data_iter)


#Treinamento e validação
def train_validate(model, train_iter, test_iter, optimizer, loss, num_epochs):
    print('training on', device)
    for epoch in range(num_epochs):
        model.train()
        train_l_sum, train_acc_sum, n, start = 0.0, 0.0, 0, time.time()
        for X, y in train_iter:
            X = X.to(device)
            y = y.to(device)
            y_pred = model(X)
            optimizer.zero_grad()
            l = loss(y_pred, y).sum()
            l.backward()
            optimizer.step()
            train_l_sum += l.item()
            train_acc_sum += (y_pred.argmax(axis=1) == y).sum().item()
            n += y.size()[0]
        test_acc, test_loss = evaluate_accuracy(test_iter, model, loss)
        #Update train/val loss and acc for the epoch
        train_losses.append(train_l_sum / len(train_iter))
        train_correct.append(train_acc_sum / n)
        test_losses.append(test_loss)
        test_correct.append(test_acc)
        print('epoch %d, train loss %.4f, train acc %.3f, test loss %.4f, ''test acc %.3f, time %.1f min' % (epoch + 1, train_l_sum / len(train_iter), train_acc_sum / n, test_loss, test_acc, (time.time() - start) / 60))



#Checa a acurácia e outras métricas(Precision, Recall, F1) no conjunto de testes
def check_accuracy_test_metrics(loader, model):
    num_correct = 0
    num_samples = 0
    model.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device)
            y = y.to(device=device)
            scores = model(x)
            _, predictions = scores.max(1)
            num_correct += (predictions == y).sum()
            num_samples += predictions.size(0)
            y_true.extend(y.cpu().numpy())
            y_pred.extend(predictions.cpu().numpy())
            
        accuracy = float(num_correct) / float(num_samples) * 100
        f1 = f1_score(y_true, y_pred, average='macro')
        precision = precision_score(y_true, y_pred, average='macro')
        recall = recall_score(y_true, y_pred, average='macro')
        
        print(f'Accuracy: {accuracy:.2f}%, Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1:.2f}')
        
        cm = confusion_matrix(y_true, y_pred)
        classes = np.arange(23)
        fig, ax = plt.subplots(figsize=(15, 15))  # Set the figsize parameter to increase the size of the image
        im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        ax.figure.colorbar(im, ax=ax)
        ax.set(xticks=np.arange(cm.shape[1]),
               yticks=np.arange(cm.shape[0]),
               xticklabels=classes, yticklabels=classes,
               ylabel='True label',
               xlabel='Predicted label')
        plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
        fmt = '.2f'
        thresh = cm.max() / 2.
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                ax.text(j, i, format(cm[i, j], fmt),
                        ha="center", va="center",
                        color="white" if cm[i, j] > thresh else "black")
        fig.tight_layout()
        
        return

# %% [markdown]
# ## Primeiro Treinamento ##

# %%
args
# Out:
# {'batch_size': 256, 'num_workers': 4, 'num_epochs': 50, 'learning_rate': 0.001}

# %%
#Tamanho dos dados de treino, teste e validação
train.shape, test.shape, val.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-28afceedb784> in <module>
#       1 #Tamanho dos dados de treino, teste e validação
# ----> 2 train.shape, test.shape, val.shape
#
# NameError: name 'train' is not defined

# %% [markdown]
# ### Data Augmentation ###
# Para o treinamento, foi utilizada a técnica de Data Augmentation, que consiste em uma técnica de pré-processamento de dados usada para aumentar o tamanho do conjunto de dados, através da geração de novas amostras. Para gerar novas amostras, diversas transformações podem ser realizadas, como rotações, reflexões, escalas, translações, entre outras. Essa técnica permite aumentar a diversidade e a variação dos dados, o que resulta em um melho desempenho e generalização do modelo

# %%
transform = T.Compose([
    T.ToPILImage(),
    CropCenter(256),
    T.RandomGrayscale(0.5),
    T.RandomAutocontrast(0.5),
    T.RandomHorizontalFlip(0.5),
    T.Resize(224),
    T.ColorJitter(brightness=(0.5,1.5)),
    T.ToTensor()
])

train_dataset = AnimalImageDataset(csv_file = 'training_data_d1.csv', root_dir = '', transform = transform)
val_dataset = AnimalImageDataset(csv_file = 'validation_data_d1.csv', root_dir = '', transform = transform)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6d4269ccabad> in <module>
#       1 transform = T.Compose([
#       2     T.ToPILImage(),
# ----> 3     CropCenter(256),
#       4     T.RandomGrayscale(0.5),
#       5     T.RandomAutocontrast(0.5),
#
# NameError: name 'CropCenter' is not defined

# %%
#Definição da função de perda e do otimizador

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = args['learning_rate'])

# %%
#Treinamento

train_iter, val_iter = load_data()

start_time = time.time()

train_validate(model, train_iter, val_iter, optimizer, criterion, args['num_epochs'])

print(f'Tempo de treinamento: {((time.time() - start_time)/60):.2f} minutos')
# Out:
# training on cuda:0
# epoch 1, train loss 1.1810, train acc 0.697, test loss 0.8822, test acc 0.730, time 0.9 min
# epoch 2, train loss 0.5407, train acc 0.833, test loss 0.9896, test acc 0.718, time 0.9 min
# epoch 3, train loss 0.4244, train acc 0.868, test loss 0.6498, test acc 0.798, time 0.9 min
# epoch 4, train loss 0.3292, train acc 0.895, test loss 1.6472, test acc 0.632, time 0.9 min
# epoch 5, train loss 0.2756, train acc 0.911, test loss 0.7337, test acc 0.794, time 1.0 min
# epoch 6, train loss 0.2405, train acc 0.922, test loss 0.8019, test acc 0.781, time 1.0 min
# epoch 7, train loss 0.2102, train acc 0.933, test loss 0.7054, test acc 0.807, time 1.0 min
# epoch 8, train loss 0.1744, train acc 0.941, test loss 0.7481, test acc 0.814, time 1.0 min
# epoch 9, train loss 0.1565, train acc 0.950, test loss 0.7971, test acc 0.795, time 1.0 min
# epoch 10, train loss 0.1383, train acc 0.956, test loss 0.7660, test acc 0.818, time 1.0 min
# epoch 11, train loss 0.1085, train acc 0.967, test loss 0.9553, test acc 0.785, time 1.0 min
# epoch 12, train loss 0.1038, train acc 0.967, test loss 0.7335, test acc 0.836, time 1.0 min
# epoch 13, train loss 0.0833, train acc 0.975, test loss 0.6986, test acc 0.841, time 1.0 min
# epoch 14, train loss 0.0849, train acc 0.974, test loss 0.8695, test acc 0.824, time 1.0 min
# epoch 15, train loss 0.0793, train acc 0.977, test loss 0.7845, test acc 0.827, time 1.0 min
# epoch 16, train loss 0.0751, train acc 0.978, test loss 0.7761, test acc 0.821, time 1.0 min
# epoch 17, train loss 0.0792, train acc 0.975, test loss 0.8182, test acc 0.815, time 1.0 min
# epoch 18, train loss 0.0577, train acc 0.983, test loss 0.7887, test acc 0.830, time 1.0 min
# epoch 19, train loss 0.0508, train acc 0.985, test loss 0.8502, test acc 0.825, time 1.0 min
# epoch 20, train loss 0.0602, train acc 0.982, test loss 1.0873, test acc 0.798, time 1.0 min
# epoch 21, train loss 0.0596, train acc 0.981, test loss 0.9356, test acc 0.814, time 1.0 min
# epoch 22, train loss 0.0607, train acc 0.982, test loss 0.8603, test acc 0.813, time 1.0 min
# epoch 23, train loss 0.0506, train acc 0.984, test loss 0.8901, test acc 0.831, time 1.0 min
# epoch 24, train loss 0.0645, train acc 0.979, test loss 0.9075, test acc 0.811, time 1.0 min
# epoch 25, train loss 0.0545, train acc 0.984, test loss 0.7990, test acc 0.833, time 1.0 min
# epoch 26, train loss 0.0532, train acc 0.983, test loss 0.9789, test acc 0.812, time 1.0 min
# epoch 27, train loss 0.0474, train acc 0.985, test loss 0.9029, test acc 0.817, time 1.0 min
# epoch 28, train loss 0.0523, train acc 0.985, test loss 0.7939, test acc 0.836, time 1.0 min
# epoch 29, train loss 0.0546, train acc 0.983, test loss 0.9343, test acc 0.821, time 1.0 min
# epoch 30, train loss 0.0482, train acc 0.986, test loss 0.8493, test acc 0.835, time 1.1 min
# epoch 31, train loss 0.0459, train acc 0.986, test loss 0.7841, test acc 0.842, time 1.0 min
# epoch 32, train loss 0.0368, train acc 0.989, test loss 0.8065, test acc 0.845, time 1.0 min
# epoch 33, train loss 0.0380, train acc 0.989, test loss 0.8827, test acc 0.827, time 1.0 min
# epoch 34, train loss 0.0412, train acc 0.987, test loss 0.8949, test acc 0.822, time 1.0 min
# epoch 35, train loss 0.0319, train acc 0.990, test loss 0.8669, test acc 0.827, time 1.0 min
# epoch 36, train loss 0.0458, train acc 0.986, test loss 0.9277, test acc 0.821, time 1.0 min
# epoch 37, train loss 0.0378, train acc 0.988, test loss 0.8761, test acc 0.835, time 1.0 min
# epoch 38, train loss 0.0390, train acc 0.988, test loss 0.9344, test acc 0.830, time 1.0 min
# epoch 39, train loss 0.0366, train acc 0.989, test loss 0.8986, test acc 0.846, time 1.0 min
# epoch 40, train loss 0.0316, train acc 0.990, test loss 0.9928, test acc 0.828, time 1.0 min
# epoch 41, train loss 0.0358, train acc 0.989, test loss 0.8386, test acc 0.848, time 1.0 min
# epoch 42, train loss 0.0301, train acc 0.991, test loss 0.9664, test acc 0.833, time 1.0 min
# epoch 43, train loss 0.0303, train acc 0.991, test loss 0.9055, test acc 0.823, time 1.0 min
# epoch 44, train loss 0.0308, train acc 0.990, test loss 0.9215, test acc 0.821, time 1.0 min
# epoch 45, train loss 0.0408, train acc 0.987, test loss 0.9393, test acc 0.822, time 1.0 min
# epoch 46, train loss 0.0402, train acc 0.989, test loss 0.9149, test acc 0.838, time 1.0 min
# epoch 47, train loss 0.0403, train acc 0.987, test loss 0.9511, test acc 0.833, time 1.0 min
# epoch 48, train loss 0.0316, train acc 0.991, test loss 0.9295, test acc 0.836, time 1.0 min
# epoch 49, train loss 0.0291, train acc 0.992, test loss 0.8990, test acc 0.843, time 1.0 min
# epoch 50, train loss 0.0298, train acc 0.990, test loss 0.9288, test acc 0.840, time 1.0 min
# Tempo de treinamento: 50.68 minutos

# %%
#Acurácia dos dados de teste e matrix de confusão

teste_data = AnimalImageDataset(csv_file = "testing_data_d1.csv",
                                root_dir = '',
                                transform = transform)

teste_loader = DataLoader(dataset=teste_data,
                          batch_size = args['batch_size'],
                          shuffle=False)

check_accuracy_test(teste_loader, model)
# Out:
# Got 3651 / 4350 with accuracy 83.93 %

# %% [markdown]
# #### Comportamento da Loss ao decorrer da época no Primeiro Treinamento ####

# %%
figure(figsize=(6, 4), dpi=100)

plt.plot(train_losses, label = 'training loss')
plt.plot(test_losses, label = 'test loss')
plt.title('Loss at end of each epoch')
plt.legend()

# %% [markdown]
# ## Segundo Treinamento

# %%
#Aumentando o número de épocas
args['num_epochs'] = 100

# %%
transform = T.Compose([
    T.ToPILImage(),
    T.RandomGrayscale(0.5),
    T.RandomAutocontrast(0.5),
    T.RandomHorizontalFlip(0.5),
    T.RandomRotation(15),
    T.Resize(224),
    T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    T.ToTensor()
])

train_dataset = AnimalImageDataset(csv_file = 'training_data_d1.csv', root_dir = '', transform = transform)
val_dataset = AnimalImageDataset(csv_file = 'validation_data_d1.csv', root_dir = '', transform = transform)

train_iter, val_iter = load_data()

#Training
start_time = time.time()

train_validate(model, train_iter, val_iter, optimizer, criterion, args['num_epochs'])

print(f'Tempo de treinamento: {((time.time() - start_time)/60):.2f} minutos')
# Out:
# epoch 41, train loss 0.0476, train acc 0.984, test loss 0.7081, test acc 0.850, time 1.1 min
# epoch 42, train loss 0.0456, train acc 0.984, test loss 0.8175, test acc 0.831, time 1.1 min
# epoch 43, train loss 0.0462, train acc 0.983, test loss 0.8291, test acc 0.838, time 1.1 min
# epoch 44, train loss 0.0491, train acc 0.983, test loss 0.9058, test acc 0.821, time 1.0 min
# epoch 45, train loss 0.0504, train acc 0.982, test loss 0.8231, test acc 0.833, time 1.0 min
# epoch 46, train loss 0.0438, train acc 0.985, test loss 0.8726, test acc 0.832, time 1.1 min
# epoch 47, train loss 0.0452, train acc 0.985, test loss 0.7271, test acc 0.852, time 1.0 min
# epoch 48, train loss 0.0474, train acc 0.984, test loss 0.7960, test acc 0.839, time 1.0 min
# epoch 49, train loss 0.0602, train acc 0.981, test loss 0.9170, test acc 0.828, time 1.0 min
# epoch 50, train loss 0.0555, train acc 0.981, test loss 0.8583, test acc 0.833, time 1.0 min
# epoch 51, train loss 0.0517, train acc 0.982, test loss 0.7915, test acc 0.842, time 1.0 min
# epoch 52, train loss 0.0475, train acc 0.983, test loss 0.8728, test acc 0.843, time 1.0 min
# epoch 53, train loss 0.0538, train acc 0.983, test loss 0.8352, test acc 0.846, time 1.0 min
# epoch 54, train loss 0.0494, train acc 0.985, test loss 0.8984, test acc 0.832, time 1.0 min
# epoch 55, train loss 0.0389, train acc 0.987, test loss 0.8103, test acc 0.839, time 1.0 min
# epoch 56, train loss 0.0387, train acc 0.987, test loss 0.7657, test acc 0.847, time 1.1 min
# epoch 57, train loss 0.0371, train acc 0.988, test loss 0.7448, test acc 0.852, time 1.0 min
# epoch 58, train loss 0.0323, train acc 0.988, test loss 1.0806, test acc 0.805, time 1.0 min
# epoch 59, train loss 0.0432, train acc 0.986, test loss 0.8279, test acc 0.841, time 1.1 min
# epoch 60, train loss 0.0471, train acc 0.985, test loss 0.9162, test acc 0.824, time 1.1 min
# epoch 61, train loss 0.0459, train acc 0.985, test loss 0.8143, test acc 0.846, time 1.0 min
# epoch 62, train loss 0.0438, train acc 0.987, test loss 0.8809, test acc 0.833, time 1.0 min
# epoch 63, train loss 0.0469, train acc 0.984, test loss 0.8978, test acc 0.836, time 1.0 min
# epoch 64, train loss 0.0447, train acc 0.985, test loss 0.9252, test acc 0.837, time 1.0 min
# epoch 65, train loss 0.0463, train acc 0.984, test loss 0.8883, test acc 0.833, time 1.1 min
# epoch 66, train loss 0.0479, train acc 0.985, test loss 0.8502, test acc 0.843, time 1.0 min
# epoch 67, train loss 0.0422, train acc 0.985, test loss 0.8688, test acc 0.827, time 1.0 min
# epoch 68, train loss 0.0428, train acc 0.985, test loss 0.7569, test acc 0.846, time 1.0 min
# epoch 69, train loss 0.0422, train acc 0.987, test loss 1.0204, test acc 0.819, time 1.0 min
# epoch 70, train loss 0.0404, train acc 0.986, test loss 0.8981, test acc 0.834, time 1.1 min
# epoch 71, train loss 0.0413, train acc 0.986, test loss 0.9382, test acc 0.840, time 1.0 min
# epoch 72, train loss 0.0438, train acc 0.986, test loss 0.8332, test acc 0.842, time 1.0 min
# epoch 73, train loss 0.0313, train acc 0.990, test loss 0.8196, test acc 0.848, time 1.0 min
# epoch 74, train loss 0.0304, train acc 0.990, test loss 0.8368, test acc 0.839, time 1.0 min
# epoch 75, train loss 0.0311, train acc 0.990, test loss 0.8920, test acc 0.846, time 1.0 min
# epoch 76, train loss 0.0302, train acc 0.991, test loss 0.9355, test acc 0.837, time 1.0 min
# epoch 77, train loss 0.0320, train acc 0.990, test loss 0.8308, test acc 0.838, time 1.0 min
# epoch 78, train loss 0.0272, train acc 0.992, test loss 0.9401, test acc 0.831, time 1.0 min
# epoch 79, train loss 0.0276, train acc 0.991, test loss 0.8570, test acc 0.850, time 1.0 min
# epoch 80, train loss 0.0274, train acc 0.991, test loss 0.9154, test acc 0.831, time 1.0 min
# epoch 81, train loss 0.0305, train acc 0.990, test loss 0.8888, test acc 0.850, time 1.0 min
# epoch 82, train loss 0.0303, train acc 0.990, test loss 0.9097, test acc 0.834, time 1.0 min
# epoch 83, train loss 0.0355, train acc 0.987, test loss 0.8813, test acc 0.838, time 1.0 min
# epoch 84, train loss 0.0303, train acc 0.990, test loss 0.9899, test acc 0.827, time 1.0 min
# epoch 85, train loss 0.0353, train acc 0.988, test loss 0.9652, test acc 0.831, time 1.0 min
# epoch 86, train loss 0.0339, train acc 0.989, test loss 0.8510, test acc 0.843, time 1.0 min
# epoch 87, train loss 0.0262, train acc 0.992, test loss 0.9056, test acc 0.846, time 1.0 min
# epoch 88, train loss 0.0327, train acc 0.989, test loss 0.9360, test acc 0.834, time 1.0 min
# epoch 89, train loss 0.0329, train acc 0.989, test loss 0.9722, test acc 0.820, time 1.0 min
# epoch 90, train loss 0.0405, train acc 0.987, test loss 1.0201, test acc 0.829, time 1.0 min
# epoch 91, train loss 0.0445, train acc 0.985, test loss 0.9895, test acc 0.829, time 1.0 min
# epoch 92, train loss 0.0422, train acc 0.985, test loss 1.8462, test acc 0.741, time 1.0 min
# epoch 93, train loss 0.0447, train acc 0.983, test loss 1.0188, test acc 0.814, time 1.0 min
# epoch 94, train loss 0.0420, train acc 0.985, test loss 0.9659, test acc 0.828, time 1.1 min
# epoch 95, train loss 0.0413, train acc 0.988, test loss 1.2128, test acc 0.799, time 1.1 min
# epoch 96, train loss 0.0288, train acc 0.990, test loss 1.0676, test acc 0.813, time 1.0 min
# epoch 97, train loss 0.0321, train acc 0.989, test loss 1.0248, test acc 0.822, time 1.0 min
# epoch 98, train loss 0.0398, train acc 0.987, test loss 1.2465, test acc 0.794, time 1.0 min
# epoch 99, train loss 0.0291, train acc 0.991, test loss 1.0023, test acc 0.823, time 1.1 min
# epoch 100, train loss 0.0328, train acc 0.989, test loss 0.9848, test acc 0.827, time 1.1 min
# Tempo de treinamento: 105.61 minutos

# %%
#Acurácia dos dados de teste e matrix de confusão
teste_data = AnimalImageDataset(csv_file = "testing_data_d1.csv",
                                root_dir = '',
                                transform = transform)

teste_loader = DataLoader(dataset=teste_data,
                          batch_size = args['batch_size'],
                          shuffle=False)

check_accuracy_test(teste_loader, model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fe3938cbda1f> in <module>
#       1 #Acurácia dos dados de teste e matrix de confusão
# ----> 2 teste_data = AnimalImageDataset(csv_file = "testing_data_d1.csv",
#       3                                 root_dir = '',
#       4                                 transform = transform)
#       5
#
# NameError: name 'AnimalImageDataset' is not defined

# %%
figure(figsize=(6, 4), dpi=100)

plt.plot(train_losses[50:], label = 'training loss')
plt.plot(test_losses[50:], label = 'test loss')
plt.title('Loss at end of each epoch')
plt.legend()

# %% [markdown]
# ## Terceiro Treinamento

# %%
#Alterando a learning rate para 0.001

# %%
args
# Out:
# {'batch_size': 256,
#  'num_workers': 4,
#  'num_epochs': 100,
#  'learning_rate': 0.001}

# %%
args['learning_rate'] = 0.0001

# %%
transform = T.Compose([
    T.ToPILImage(),
    T.RandomCrop(256, padding=4),
    T.RandomGrayscale(0.1),
    T.RandomAutocontrast(0.1),
    T.RandomHorizontalFlip(0.2),
    T.Resize(224),
    T.ToTensor(),
    T.Normalize([0, 0, 0], [1, 1, 1])
])

train_dataset = AnimalImageDataset(csv_file = 'training_data_d1.csv', root_dir = '', transform = transform)
val_dataset = AnimalImageDataset(csv_file = 'validation_data_d1.csv', root_dir = '', transform = transform)

train_iter, val_iter = load_data()

#Training
start_time = time.time()

train_validate(model, train_iter, val_iter, optimizer, criterion, args['num_epochs'])

print(f'Tempo de treinamento: {((time.time() - start_time)/60):.2f} minutos')
# Out:
# training on cuda:0
# epoch 1, train loss 1.2996, train acc 0.638, test loss 1.0606, test acc 0.682, time 0.5 min
# epoch 2, train loss 0.8623, train acc 0.729, test loss 1.0166, test acc 0.698, time 0.5 min
# epoch 3, train loss 0.7875, train acc 0.750, test loss 0.9817, test acc 0.702, time 0.5 min
# epoch 4, train loss 0.7041, train acc 0.777, test loss 0.9733, test acc 0.711, time 0.5 min
# epoch 5, train loss 0.6533, train acc 0.791, test loss 0.9017, test acc 0.742, time 0.5 min
# epoch 6, train loss 0.6198, train acc 0.799, test loss 0.9008, test acc 0.732, time 0.5 min
# epoch 7, train loss 0.5993, train acc 0.806, test loss 0.9345, test acc 0.729, time 0.5 min
# epoch 8, train loss 0.5520, train acc 0.818, test loss 0.9517, test acc 0.728, time 0.5 min
# epoch 9, train loss 0.5512, train acc 0.821, test loss 0.9752, test acc 0.721, time 0.5 min
# epoch 10, train loss 0.5200, train acc 0.829, test loss 0.8771, test acc 0.748, time 0.5 min
# epoch 11, train loss 0.4966, train acc 0.838, test loss 1.1175, test acc 0.708, time 0.5 min
# epoch 12, train loss 0.4745, train acc 0.842, test loss 0.9268, test acc 0.745, time 0.5 min
# epoch 13, train loss 0.4658, train acc 0.844, test loss 0.8907, test acc 0.748, time 0.5 min
# epoch 14, train loss 0.4502, train acc 0.849, test loss 0.9129, test acc 0.753, time 0.5 min
# epoch 15, train loss 0.4469, train acc 0.850, test loss 0.9147, test acc 0.747, time 0.5 min
# epoch 16, train loss 0.4328, train acc 0.854, test loss 0.9894, test acc 0.744, time 0.5 min
# epoch 17, train loss 0.4046, train acc 0.864, test loss 0.9651, test acc 0.752, time 0.5 min
# epoch 18, train loss 0.3992, train acc 0.868, test loss 0.9522, test acc 0.745, time 0.5 min
# epoch 19, train loss 0.3930, train acc 0.870, test loss 1.1167, test acc 0.721, time 0.5 min
# epoch 84, train loss 0.1411, train acc 0.951, test loss 1.2439, test acc 0.768, time 0.5 min
# epoch 85, train loss 0.1446, train acc 0.951, test loss 1.2080, test acc 0.776, time 0.5 min
# epoch 86, train loss 0.1422, train acc 0.950, test loss 1.2397, test acc 0.768, time 0.5 min
# epoch 87, train loss 0.1536, train acc 0.946, test loss 1.1855, test acc 0.770, time 0.5 min
# epoch 88, train loss 0.1328, train acc 0.956, test loss 1.2403, test acc 0.766, time 0.5 min
# epoch 89, train loss 0.1472, train acc 0.950, test loss 1.2435, test acc 0.761, time 0.5 min
# epoch 90, train loss 0.1370, train acc 0.953, test loss 1.2656, test acc 0.752, time 0.5 min
# epoch 91, train loss 0.1435, train acc 0.952, test loss 1.3760, test acc 0.743, time 0.5 min
# epoch 92, train loss 0.1335, train acc 0.955, test loss 1.2952, test acc 0.753, time 0.5 min
# epoch 93, train loss 0.1455, train acc 0.951, test loss 1.3008, test acc 0.762, time 0.5 min
# epoch 94, train loss 0.1394, train acc 0.950, test loss 1.3375, test acc 0.766, time 0.5 min
# epoch 95, train loss 0.1415, train acc 0.951, test loss 1.3002, test acc 0.759, time 0.5 min
# epoch 96, train loss 0.1347, train acc 0.953, test loss 1.2982, test acc 0.767, time 0.5 min
# epoch 97, train loss 0.1300, train acc 0.957, test loss 1.2706, test acc 0.768, time 0.5 min
# epoch 98, train loss 0.1382, train acc 0.952, test loss 1.3150, test acc 0.751, time 0.5 min
# epoch 99, train loss 0.1338, train acc 0.952, test loss 1.3292, test acc 0.756, time 0.5 min
# epoch 100, train loss 0.1383, train acc 0.952, test loss 1.2914, test acc 0.745, time 0.5 min
# Tempo de treinamento: 49.39 minutos

# %%
#Acurácia dos dados de teste e matrix de confusão
teste_data = AnimalImageDataset(csv_file = "testing_data_d1.csv",
                                root_dir = '',
                                transform = transform)

teste_loader = DataLoader(dataset=teste_data,
                          batch_size = args['batch_size'],
                          shuffle=False)

check_accuracy_test(teste_loader, model)
# Out:
# Accuracy: 74.69%, Precision: 0.67, Recall: 0.62, F1-Score: 0.64

# %%
figure(figsize=(6, 4), dpi=100)

plt.plot(train_losses[100:], label = 'training loss')
plt.plot(test_losses[100:], label = 'test loss')
plt.title('Loss at end of each epoch')
plt.legend()

# %% [markdown]
# ## Quarto Treinamento

# %%
#Diminuindo a learning rate e alterando o número de epochs para 200

# %%
train_losses = []
test_losses = []
train_correct = []
test_correct = []

# %%
args
# Out:
# {'batch_size': 256,
#  'num_workers': 4,
#  'num_epochs': 100,
#  'learning_rate': 0.0001}

# %%
args['learning_rate'] = 0.0001
args['num_epochs'] = 200

# %%
transform = T.Compose([
    T.ToPILImage(),
    T.RandomGrayscale(0.5),
    T.RandomHorizontalFlip(0.5),
    T.RandomRotation(15),
    T.Resize(224),
    T.ColorJitter(brightness=0.4, contrast=0.25, saturation=0.25, hue=0.1),
    T.ToTensor(),
])

train_dataset = AnimalImageDataset(csv_file = 'training_data_d1.csv', root_dir = '', transform = transform)
val_dataset = AnimalImageDataset(csv_file = 'validation_data_d1.csv', root_dir = '', transform = transform)

optimizer = optim.Adam(model.parameters(), lr = args['learning_rate'])
train_iter, val_iter = load_data()

#Training
start_time = time.time()

train_validate(model, train_iter, val_iter, optimizer, criterion, args['num_epochs'])

print(f'Tempo de treinamento: {((time.time() - start_time)/60):.2f} minutos')
# Out:
# training on cuda:0
# epoch 1, train loss 0.3740, train acc 0.884, test loss 0.8088, test acc 0.801, time 1.0 min
# epoch 2, train loss 0.2231, train acc 0.927, test loss 0.7378, test acc 0.823, time 1.0 min
# epoch 3, train loss 0.1710, train acc 0.942, test loss 0.6886, test acc 0.830, time 1.0 min
# epoch 4, train loss 0.1453, train acc 0.951, test loss 0.6557, test acc 0.839, time 1.0 min
# epoch 5, train loss 0.1200, train acc 0.961, test loss 0.6653, test acc 0.847, time 1.0 min
# epoch 6, train loss 0.1011, train acc 0.968, test loss 0.6754, test acc 0.846, time 1.0 min
# epoch 7, train loss 0.0947, train acc 0.969, test loss 0.7144, test acc 0.839, time 1.0 min
# epoch 8, train loss 0.0884, train acc 0.970, test loss 0.6938, test acc 0.843, time 1.0 min
# epoch 9, train loss 0.0733, train acc 0.977, test loss 0.6978, test acc 0.846, time 1.0 min
# epoch 10, train loss 0.0709, train acc 0.977, test loss 0.7006, test acc 0.847, time 1.0 min
# epoch 11, train loss 0.0714, train acc 0.976, test loss 0.7234, test acc 0.846, time 1.0 min
# epoch 12, train loss 0.0579, train acc 0.981, test loss 0.7255, test acc 0.854, time 1.0 min
# epoch 13, train loss 0.0566, train acc 0.982, test loss 0.7016, test acc 0.854, time 1.0 min
# epoch 14, train loss 0.0521, train acc 0.982, test loss 0.7075, test acc 0.856, time 1.0 min
# epoch 15, train loss 0.0507, train acc 0.985, test loss 0.7358, test acc 0.855, time 1.0 min
# epoch 16, train loss 0.0408, train acc 0.987, test loss 0.7428, test acc 0.855, time 1.0 min
# epoch 17, train loss 0.0368, train acc 0.989, test loss 0.7498, test acc 0.855, time 1.0 min
# epoch 18, train loss 0.0384, train acc 0.988, test loss 0.7436, test acc 0.852, time 1.0 min
# epoch 19, train loss 0.0366, train acc 0.989, test loss 0.7386, test acc 0.861, time 1.0 min
# epoch 20, train loss 0.0344, train acc 0.989, test loss 0.7437, test acc 0.855, time 1.0 min
# epoch 21, train loss 0.0310, train acc 0.990, test loss 0.7492, test acc 0.856, time 1.0 min
# epoch 22, train loss 0.0295, train acc 0.991, test loss 0.7276, test acc 0.861, time 1.0 min
# epoch 23, train loss 0.0316, train acc 0.990, test loss 0.7659, test acc 0.857, time 1.0 min
# epoch 24, train loss 0.0283, train acc 0.992, test loss 0.7845, test acc 0.857, time 1.0 min
# epoch 25, train loss 0.0277, train acc 0.991, test loss 0.7766, test acc 0.857, time 1.0 min
# epoch 26, train loss 0.0259, train acc 0.991, test loss 0.7696, test acc 0.863, time 1.0 min
# epoch 27, train loss 0.0242, train acc 0.993, test loss 0.7998, test acc 0.855, time 1.0 min
# epoch 28, train loss 0.0244, train acc 0.992, test loss 0.7888, test acc 0.857, time 1.0 min
# epoch 29, train loss 0.0222, train acc 0.993, test loss 0.8008, test acc 0.856, time 1.0 min
# epoch 30, train loss 0.0215, train acc 0.993, test loss 0.8105, test acc 0.849, time 1.0 min
# epoch 31, train loss 0.0187, train acc 0.995, test loss 0.7766, test acc 0.859, time 1.0 min
# epoch 32, train loss 0.0186, train acc 0.995, test loss 0.8127, test acc 0.857, time 1.0 min
# epoch 33, train loss 0.0197, train acc 0.994, test loss 0.7960, test acc 0.858, time 1.0 min
# epoch 34, train loss 0.0150, train acc 0.996, test loss 0.8436, test acc 0.856, time 1.0 min
# epoch 35, train loss 0.0167, train acc 0.995, test loss 0.8267, test acc 0.854, time 1.0 min
# epoch 36, train loss 0.0174, train acc 0.995, test loss 0.8577, test acc 0.854, time 1.0 min
# epoch 37, train loss 0.0200, train acc 0.994, test loss 0.8172, test acc 0.858, time 1.0 min
# epoch 38, train loss 0.0152, train acc 0.996, test loss 0.7824, test acc 0.860, time 1.0 min
# epoch 39, train loss 0.0143, train acc 0.996, test loss 0.8167, test acc 0.861, time 1.0 min
# epoch 40, train loss 0.0131, train acc 0.996, test loss 0.8213, test acc 0.861, time 1.0 min
# epoch 41, train loss 0.0138, train acc 0.996, test loss 0.8456, test acc 0.860, time 1.0 min
# epoch 42, train loss 0.0153, train acc 0.994, test loss 0.8426, test acc 0.857, time 1.0 min
# epoch 43, train loss 0.0122, train acc 0.997, test loss 0.8415, test acc 0.862, time 1.0 min
# epoch 44, train loss 0.0119, train acc 0.996, test loss 0.8500, test acc 0.862, time 1.0 min
# epoch 45, train loss 0.0107, train acc 0.996, test loss 0.8542, test acc 0.856, time 1.0 min
# epoch 46, train loss 0.0108, train acc 0.997, test loss 0.8273, test acc 0.855, time 1.0 min
# epoch 47, train loss 0.0118, train acc 0.996, test loss 0.8615, test acc 0.861, time 1.0 min
# epoch 48, train loss 0.0115, train acc 0.997, test loss 0.8504, test acc 0.859, time 1.0 min
# epoch 49, train loss 0.0109, train acc 0.997, test loss 0.8400, test acc 0.864, time 1.0 min
# epoch 50, train loss 0.0095, train acc 0.998, test loss 0.8590, test acc 0.857, time 1.0 min
# epoch 51, train loss 0.0084, train acc 0.998, test loss 0.8597, test acc 0.855, time 1.0 min
# epoch 52, train loss 0.0100, train acc 0.997, test loss 0.8732, test acc 0.856, time 1.0 min
# epoch 53, train loss 0.0102, train acc 0.997, test loss 0.8301, test acc 0.864, time 1.0 min
# epoch 54, train loss 0.0087, train acc 0.998, test loss 0.8515, test acc 0.862, time 1.0 min
# epoch 55, train loss 0.0082, train acc 0.998, test loss 0.8931, test acc 0.860, time 1.0 min
# epoch 56, train loss 0.0082, train acc 0.998, test loss 0.8641, test acc 0.861, time 1.0 min
# epoch 57, train loss 0.0082, train acc 0.998, test loss 0.8498, test acc 0.859, time 1.0 min
# epoch 58, train loss 0.0086, train acc 0.997, test loss 0.8670, test acc 0.858, time 1.0 min
# epoch 59, train loss 0.0090, train acc 0.997, test loss 0.8794, test acc 0.858, time 1.0 min
# epoch 60, train loss 0.0084, train acc 0.998, test loss 0.8700, test acc 0.859, time 1.0 min
# epoch 61, train loss 0.0076, train acc 0.998, test loss 0.8870, test acc 0.862, time 1.0 min
# epoch 62, train loss 0.0070, train acc 0.998, test loss 0.8899, test acc 0.860, time 1.0 min
# epoch 63, train loss 0.0082, train acc 0.998, test loss 0.8813, test acc 0.863, time 1.0 min
# epoch 64, train loss 0.0077, train acc 0.997, test loss 0.8847, test acc 0.859, time 1.0 min
# epoch 65, train loss 0.0078, train acc 0.997, test loss 0.8851, test acc 0.863, time 1.0 min
# epoch 66, train loss 0.0093, train acc 0.997, test loss 0.8645, test acc 0.860, time 1.0 min
# epoch 67, train loss 0.0082, train acc 0.997, test loss 0.9030, test acc 0.859, time 1.0 min
# epoch 68, train loss 0.0063, train acc 0.998, test loss 0.8854, test acc 0.862, time 1.0 min
# epoch 69, train loss 0.0076, train acc 0.998, test loss 0.8851, test acc 0.860, time 1.0 min
# epoch 70, train loss 0.0085, train acc 0.998, test loss 0.8708, test acc 0.864, time 1.0 min
# epoch 71, train loss 0.0068, train acc 0.998, test loss 0.9040, test acc 0.860, time 1.0 min
# epoch 72, train loss 0.0055, train acc 0.999, test loss 0.9201, test acc 0.859, time 1.0 min
# epoch 73, train loss 0.0044, train acc 0.999, test loss 0.8990, test acc 0.859, time 1.0 min
# epoch 74, train loss 0.0050, train acc 0.999, test loss 0.9486, test acc 0.855, time 1.0 min
# epoch 75, train loss 0.0051, train acc 0.999, test loss 0.9042, test acc 0.865, time 1.0 min
# epoch 76, train loss 0.0054, train acc 0.999, test loss 0.8993, test acc 0.866, time 1.0 min
# epoch 77, train loss 0.0055, train acc 0.999, test loss 0.9244, test acc 0.861, time 1.0 min
# epoch 78, train loss 0.0062, train acc 0.999, test loss 0.9348, test acc 0.859, time 1.0 min
# epoch 79, train loss 0.0054, train acc 0.999, test loss 0.8919, test acc 0.857, time 1.0 min
# epoch 80, train loss 0.0060, train acc 0.998, test loss 0.9131, test acc 0.866, time 1.0 min
# epoch 81, train loss 0.0057, train acc 0.998, test loss 0.8871, test acc 0.862, time 1.0 min
# epoch 82, train loss 0.0048, train acc 0.999, test loss 0.9168, test acc 0.863, time 1.0 min
# epoch 83, train loss 0.0041, train acc 0.999, test loss 0.9235, test acc 0.865, time 1.0 min
# epoch 84, train loss 0.0038, train acc 0.999, test loss 0.9092, test acc 0.865, time 1.0 min
# epoch 85, train loss 0.0047, train acc 0.999, test loss 0.9112, test acc 0.866, time 1.0 min
# epoch 86, train loss 0.0046, train acc 0.998, test loss 0.9646, test acc 0.859, time 1.0 min
# epoch 87, train loss 0.0045, train acc 0.999, test loss 0.9434, test acc 0.861, time 1.0 min
# epoch 88, train loss 0.0043, train acc 0.999, test loss 0.9472, test acc 0.860, time 1.0 min
# epoch 89, train loss 0.0060, train acc 0.998, test loss 0.8972, test acc 0.863, time 1.0 min
# epoch 90, train loss 0.0044, train acc 0.999, test loss 0.9112, test acc 0.862, time 1.0 min
# epoch 91, train loss 0.0047, train acc 0.999, test loss 0.9266, test acc 0.861, time 1.0 min
# epoch 92, train loss 0.0050, train acc 0.999, test loss 0.9670, test acc 0.861, time 1.0 min
# epoch 93, train loss 0.0044, train acc 0.999, test loss 0.9694, test acc 0.861, time 1.0 min
# epoch 94, train loss 0.0044, train acc 0.999, test loss 0.9642, test acc 0.859, time 1.0 min
# epoch 95, train loss 0.0052, train acc 0.998, test loss 0.9701, test acc 0.859, time 1.0 min
# epoch 96, train loss 0.0048, train acc 0.999, test loss 0.9588, test acc 0.861, time 1.0 min
# epoch 97, train loss 0.0038, train acc 0.999, test loss 0.9178, test acc 0.864, time 1.0 min
# epoch 98, train loss 0.0033, train acc 0.999, test loss 0.9466, test acc 0.865, time 1.0 min
# epoch 99, train loss 0.0041, train acc 0.999, test loss 0.9524, test acc 0.862, time 1.0 min
# epoch 100, train loss 0.0051, train acc 0.998, test loss 0.9134, test acc 0.863, time 1.0 min
# epoch 101, train loss 0.0039, train acc 0.999, test loss 0.9624, test acc 0.862, time 1.0 min
# epoch 102, train loss 0.0043, train acc 0.999, test loss 0.9641, test acc 0.860, time 1.0 min
# epoch 103, train loss 0.0040, train acc 0.999, test loss 0.9372, test acc 0.857, time 1.0 min
# epoch 104, train loss 0.0040, train acc 0.999, test loss 0.9738, test acc 0.861, time 1.0 min
# epoch 105, train loss 0.0035, train acc 0.999, test loss 0.9874, test acc 0.860, time 1.0 min
# epoch 106, train loss 0.0037, train acc 0.999, test loss 1.0075, test acc 0.855, time 1.0 min
# epoch 107, train loss 0.0028, train acc 0.999, test loss 0.9426, test acc 0.858, time 1.0 min
# epoch 108, train loss 0.0042, train acc 0.999, test loss 0.9757, test acc 0.856, time 1.0 min
# epoch 109, train loss 0.0042, train acc 0.999, test loss 0.9841, test acc 0.857, time 1.0 min
# epoch 110, train loss 0.0037, train acc 0.999, test loss 0.9806, test acc 0.861, time 1.0 min
# epoch 111, train loss 0.0038, train acc 0.999, test loss 0.9912, test acc 0.859, time 1.0 min
# epoch 112, train loss 0.0039, train acc 0.999, test loss 0.9860, test acc 0.857, time 1.0 min
# epoch 113, train loss 0.0037, train acc 0.999, test loss 0.9254, test acc 0.864, time 1.0 min
# epoch 114, train loss 0.0031, train acc 0.999, test loss 1.0151, test acc 0.857, time 1.0 min
# epoch 115, train loss 0.0037, train acc 0.999, test loss 0.9784, test acc 0.864, time 1.0 min
# epoch 116, train loss 0.0037, train acc 0.999, test loss 0.9899, test acc 0.861, time 1.0 min
# epoch 117, train loss 0.0051, train acc 0.998, test loss 1.0229, test acc 0.858, time 1.0 min
# epoch 118, train loss 0.0036, train acc 0.999, test loss 0.9619, test acc 0.863, time 1.0 min
# epoch 119, train loss 0.0032, train acc 0.999, test loss 0.9918, test acc 0.859, time 1.0 min
# epoch 120, train loss 0.0032, train acc 0.999, test loss 1.0227, test acc 0.860, time 1.0 min

# %%
#Acurácia dos dados de teste e matrix de confusão
teste_data = AnimalImageDataset(csv_file = "testing_data_d1.csv",
                                root_dir = '',
                                transform = transform)

teste_loader = DataLoader(dataset=teste_data,
                          batch_size = args['batch_size'],
                          shuffle=False)

check_accuracy_test(teste_loader, model)
# Out:
# Accuracy: 84.41%, Precision: 0.79, Recall: 0.74, F1-Score: 0.76

# %%
figure(figsize=(6, 4), dpi=100)

plt.plot(train_losses, label = 'training loss')
plt.plot(test_losses, label = 'test loss')
plt.title('Loss at end of each epoch')
plt.legend()
